# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\phani\\sentinel-score-api\\data\\train_transaction.csv")
print(df.shape)
print(df['isFraud'].value_counts())
# Out:
# (590540, 394)
# isFraud
# 0    569877
# 1     20663
# Name: count, dtype: int64

# %%
drop_cols = ['TransactionDT', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6']

df = df.drop(columns=drop_cols, errors='ignore')

print(df.shape)
# Out:
# (590540, 387)
